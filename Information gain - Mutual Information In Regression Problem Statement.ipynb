# %% [markdown]
# ### Feature Selection-Information gain - mutual information In Regression Problem Statements¶

# %% [markdown]
# ### Mutual Information
# Estimate mutual information for a continuous target variable.
#
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
#
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances
#
# Mutual information is calculated between two variables and measures the reduction in uncertainty for one variable given a known value of the other variable.
#
# Inshort
#
# A quantity called mutual information measures the amount of information one can obtain from one random variable given another.
#
# The mutual information between two random variables X and Y can be stated formally as follows:
#
# #### I(X ; Y) = H(X) – H(X | Y) Where I(X ; Y) is the mutual information for X and Y, H(X) is the entropy for X and H(X | Y) is the conditional entropy for X given Y. The result has the units of bits. and bits ranges from 0 to 1

# %%
#https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
import pandas as pd
housing_df=pd.read_csv("C:\\Users\\mahen\\Downloads\\Housing price Train datset.csv")

# %%
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# our main is select the best independent features based on the SalesPrice which is dependent feature or continous target varaible

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# Before perfoming the feature selection technique we need to preprocess the data in the feature engineering process so for perfoming the feature engineering process it will take much amount of time and , so what iam doing here is iam going to select only the int and float data type features and the reason why iam not taking the categorical features because we need to perfom the encoding techinques so it will take lot of time and our main concern is to learn feature selection techinque which is mutual_information w.r.t Regression problem statement

# %%
housing_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_lst=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_cols=list(housing_df.select_dtypes(include=numeric_lst).columns)

# %%
numerical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %% [markdown]
# Above are mu numerical_columns and i want to find mutual_information w.r.t each numerical_columns  along with my sales price which is my dependent feature

# %%
housing_df=housing_df[numerical_cols]

# %%
housing_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
housing_df=housing_df.drop("Id",axis=1)

# %%
### It is always a good practice to split train and test data to avoid overfitting
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(housing_df.drop(labels=['SalePrice'],axis=1),housing_df['SalePrice'],test_size=0.3,random_state=0)

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 64            60          NaN     9375            7            5       1997
# 682          120          NaN     2887            6            5       1996
# 960           20         50.0     7207            5            7       1958
# 1384          50         60.0     9060            6            5       1939
# 1100          30         60.0     8400            2            5       1920
# ...          ...          ...      ...          ...          ...        ...
# 763           60         82.0     9430            8            5       1999
# 835           20         60.0     9600            4            7       1950
# 1216          90         68.0     8930            6            5       1978
# 559          120          NaN     3196            7            5       2003
# 684           60         58.0    16770            7            5       1998
#
# ...

# %%
X_train.isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %% [markdown]
# we even found the null values in the numerical_columns so before performing the feature selection technique we need to handle those missing values then it would not lead to any cause while we are performing the feature selection technique which is mutual information

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info=mutual_info_regression(X_train.fillna(0),y_train)
mutual_info
# Out:
# array([0.24504237, 0.21073839, 0.16667212, 0.53720698, 0.10432998,
#        0.3497914 , 0.2450626 , 0.10175937, 0.15872086, 0.00494396,
#        0.10911499, 0.382362  , 0.30959317, 0.22518056, 0.00367699,
#        0.47989924, 0.02574114, 0.00213549, 0.28020901, 0.07432905,
#        0.02680455, 0.03590476, 0.18644755, 0.18882232, 0.27091096,
#        0.37703661, 0.369536  , 0.07273677, 0.16960288, 0.00910967,
#        0.00319844, 0.02589771, 0.        , 0.        , 0.        ,
#        0.01617249])

# %% [markdown]
# Mutual information b/w 2 random variables is a non-negative value which measures the dependency between the varaibles if it is eaul to zero if and only if two random variables are independent and higher values means higher dependency
#
# and for regression problem statement the mutual_info_regresion() do calculates the above thing
# and we need to pass the X_train data which contain independent features and y_train data which contain the dependent feature or target feature and now mutual_info_regression do calculates that each independent feature how much there are depending on the target feature and it do return the output b/w 0 to 1

# %%
mutual_info=pd.Series(mutual_info)
mutual_info.index=X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.537207
# GrLivArea        0.479899
# TotalBsmtSF      0.382362
# GarageCars       0.377037
# GarageArea       0.369536
# YearBuilt        0.349791
# 1stFlrSF         0.309593
# FullBath         0.280209
# GarageYrBlt      0.270911
# YearRemodAdd     0.245063
# MSSubClass       0.245042
# 2ndFlrSF         0.225181
# LotFrontage      0.210738
# Fireplaces       0.188822
# TotRmsAbvGrd     0.186448
# OpenPorchSF      0.169603
# LotArea          0.166672
# BsmtFinSF1       0.158721
# BsmtUnfSF        0.109115
# OverallCond      0.104330
# MasVnrArea       0.101759
# HalfBath         0.074329
# WoodDeckSF       0.072737
# KitchenAbvGr     0.035905
# BedroomAbvGr     0.026805
# ScreenPorch      0.025898
# BsmtFullBath     0.025741
# YrSold           0.016172
# EnclosedPorch    0.009110
# BsmtFinSF2       0.004944
# LowQualFinSF     0.003677
# 3SsnPorch        0.003198
# BsmtHalfBath     0.002135
# PoolArea         0.000000
# MiscVal          0.000000
# ...

# %% [markdown]
# here OverallQualfeature more dependent on the target feature

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# Now based on the Selectpercentile() iam going to select the either top 10 or 20 percentile of the independent features which are more dependent on the target feature

# %%
from sklearn.feature_selection import SelectPercentile

# %%
## Selecting the top 20 percentile
selected_top_columns=SelectPercentile(mutual_info_regression,percentile=20)
selected_top_columns.fit(X_train.fillna(0),y_train)
# Out:
# SelectPercentile(percentile=20,
#                  score_func=<function mutual_info_regression at 0x000001D6933DEC20>)

# %%
selected_top_columns.get_support()
# Out:
# array([False, False, False,  True, False,  True, False, False, False,
#        False, False,  True,  True, False, False,  True, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False])

# %% [markdown]
# Whichever is true that feature comes under top 20 percentile and which ever is false that feature is not comes under top 20percentile

# %%
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %% [markdown]
# based on the above ouput that 80% of entire population are having the less dependency than GarageArea  and we can see the graph in that above bar graph whichever the features comes after GarageArea are all rest of the 80% of the population

# %% [markdown]
# #### Difference Between Information Gain And Mutual Information
# I(X ; Y) = H(X) – H(X | Y) and IG(S, a) = H(S) – H(S | a)
#
# As such, mutual information is sometimes used as a synonym for information gain. Technically, they calculate the same quantity if applied to the same data.
